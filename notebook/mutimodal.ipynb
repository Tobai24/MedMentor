# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

load_dotenv()
# Out:
# True

# %%
genai.configure()

# %%
model_info = genai.get_model("models/gemini-1.5-flash-002")
model_info
# Out:
# Model(name='models/gemini-1.5-flash-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Flash 002',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in September of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)

# %%
import time

from IPython.display import Markdown, display

def display_markdown(input):
  return display(Markdown(input))

# Start a timer and produce an output based on a text string
start_time = time.time()
model = genai.GenerativeModel(model_name="models/gemini-1.5-flash-002")
example_output = model.generate_content("Can the Gemini API work with medical images ")
end_time = time.time()

print(f"[INFO] Time taken: {end_time-start_time:.2f} seconds\nOutput:")

display_markdown(example_output.text)
# Out:
# [INFO] Time taken: 1.96 seconds
# Output:
# No, the Gemini API, in its current form, cannot directly work with medical images.  Gemini is a large language model; it excels at processing and generating text, translating languages, writing different kinds of creative content, and answering your questions in an informative way.  It doesn't have the capabilities to interpret or analyze the complex visual data contained within medical images (X-rays, CT scans, MRIs, etc.).  That requires specialized algorithms and software designed for medical image analysis.
#
# To process medical images, you would need to use separate, dedicated medical image processing tools and APIs.  These tools often employ techniques like:
#
# * **Image segmentation:** Identifying and isolating specific structures (tumors, organs, etc.) within the image.
# * **Classification:** Categorizing images based on features (e.g., cancerous vs. non-cancerous).
# * **Detection:** Locating specific objects or abnormalities within the image.
# * **Registration:** Aligning multiple images for comparison.
#
#
# While you might *indirectly* use Gemini to assist in tasks related to medical imaging (e.g., generating reports based on the *results* of image analysis performed by a specialized tool), you cannot feed medical images directly into the Gemini API for interpretation.

# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text("text") + "\n"
    return text

pdf_text = extract_text_from_pdf("radiology_textbook.pdf")
print(pdf_text[:500])  # Print first 500 characters
# Out:
# MuPDF error: format error: non-page object in page tree
